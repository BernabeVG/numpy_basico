# %%
import matplotlib.pyplot as plt

# %%
img = plt.imread('beagle.jpg')
img.shape

pixel = img[10, 10]
print(f"Valor del píxel en [10, 10] (RGB): {pixel}")

# Extraer el canal Rojo (R) de toda la imagen
canal_rojo = img[:, :, 0]
plt.imshow(canal_rojo, cmap='gray')
plt.title("Canal Rojo de la imagen")
plt.show()
# Out:
# Valor del píxel en [10, 10] (RGB): [22 35  5]
