# %% [markdown]
# # Analizando una Imagen

# %%
import matplotlib.pyplot as plt 
img = plt.imread('beagle.jpg')
img.shape

img[10,10]
# Out:
# array([22, 35,  5], dtype=uint8)

# %%
import random

def generar_matriz(N):
    matriz= []
    for i in range(N):
        fila = []
        for j in range(N):
            fila.append(random.randint(1, 10))
        matriz.append(fila)
    return matriz
N = 5

matriz_aleatoria = generar_matriz(N)
for fila in matriz_aleatoria:
    print(fila)
# Out:
# [6, 3, 2, 1, 3]
# [6, 6, 5, 5, 6]
# [1, 5, 10, 8, 6]
# [4, 1, 4, 5, 10]
# [3, 6, 8, 10, 4]

# %%
def imprimir_matriz(matriz):
    for fila in matriz:

        fila_formateada = ''.join(f'{elemento:2}' for elemento in fila)
        print(fila_formateada)

# %%
print("Matriz 5x5")
m_5 = generar_matriz(5)
imprimir_matriz(m_5)
print("=============")
print("Matriz 10x10")
m_10 = generar_matriz(10)
imprimir_matriz(m_10)
print("============")
print("Imprimir matriz 20x20")
m_20 = generar_matriz(20)
imprimir_matriz(m_20)
# Out:
# Matriz 5x5
#  7 4 8 5 9
#  1 6 5 6 4
#  5 1 5 2 4
#  3 2 1 8 9
# 10 1 2 5 7
# =============
# Matriz 10x10
#  7 7 3 3 1 2 3 9 8 2
#  6 6 2 1 8 6 2 6 5 4
#  5 7 5 8 6 8 2 8 7 2
#  3 4 9 7 9 4 4 1 8 2
#  5 3 3 810 4 8 2 2 2
#  5 1 3 510 9 110 4 6
#  3 1 4 8 3 6 4 3 110
#  8 8 3 6 710 610 5 5
#  3 5 310 8 4 6 7 3 9
#  2 6 4 5 6 1 2 2 3 8
# ============
# Imprimir matriz 20x20
#  6 3 9 8 8 5 9 7 6 3 6 1 1 3 7 2 7 9 5 1
#  6 8 6 2 8 3 3 7 8 6 5 7 4 3 4 7 110 8 1
#  1 7 6 9 5 4 2 6 4 8 4 510 1 810 7 4 1 6
#  9 9 3 5 4 9 2 9 3 610 3 8 9 9 1 4 610 8
#  510 9 5 6 2 7 1 2 7 3 8 4 810 9 8 310 5
#  3 9 3 7 3 9 5 7 6 8 410 1 8 8 6 2 510 5
#  3 2 4 2 3 8 610 8 5 1 7 9 3 6 2 910 9 7
#  3 6 4 5 110 110 2 8 1 4 4 6 4 6 4 5 2 3
#  9 1 4 2 8 6 6 7 9 6 7 1 7 9 5 1 210 2 2
#  1 210 1 8 510 3 6 110 310 6 7 9 5 3 5 4
#  3 5 7 6 8 3 210 8 5 7 6 5 1 3 3 110 7 3
#  2 310 6 4 4 9 2 9 810 3 5 7 1 6 8 4 4 5
#  7 8 1 1 9 4 5 8 2 110 3 2 4 1 3 3 4 9 9
#  8 3 6 5 2 2 6 6 8 1 1 2 6 1 8 710 2 3 4
#  4 1 9 7 8 3 2 5 5 8 8 7 2 2 8 3 2 5 510
#  3 5 7 9 2 5 4 3 6 9 3 9 6 9 6 110 9 5 4
#  4 1 410 1 2 510 4 110 1 4 6 7 8 1 9 7 4
#  4 6 2 6 210 1 5 6 5 2 4 4 5 4 9 8 4 4 1
#  810 8 6 6 1 9 5 910 5 2 7 210 8 3 7 2 6
#  3 8 9 9 3 9 5 910 4 1 810 8 8 4 9 6 9 3
